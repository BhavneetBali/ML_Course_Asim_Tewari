# %% [markdown]
# **Linear Regression:
#
# 1.Linear regression is the part of supervised learning we will have dependent variable.
# 2.In linear regression dependent variable is contineous.
# 3.Linear regression is the part of parametric supervised learning.
#
#     equation:  y= Mx + C
#
# 4.Cost/ Loss function is squared sum of error(residual).
#
#     SSE= Sum(Y actual- Y pred)^2
#
# 5.To find Best fit line we use LSE method(least square estimation).
# 6.To find out the accuracy of model we use R^2 method.
# 7.R Squared is the coefficient of determination
# 8.COD: it is the portion of total variation in the dependent variable that is explained by variation in the independent
# variable its values are lies between 0 to 1 only.
# 9.Adjested R^2: if independent variable is not providing significant improvement in R^2 then it will penalize R^2.

# %% [markdown]
# Q.What do you understand by linear regression?
#
# Linear regression is the part of supervised learning we will have dependent variable.
# In linear regression dependent variable is contineous.
# Linear regression is the part of parametric supervised learning.

# %% [markdown]
# Q.What do you understand by parametric supervised learning?
#
# The madel in which use mathamatical equation for prediction of best fit line

# %% [markdown]
# Q.What is the Cost/ Loss function of linear regression?
#
# Cost/ Loss function is squared sum of error(residual)

# %% [markdown]
# Q.In SSE why we are squaring the value/resediual?
#
# SE will nullify each other by adding as the residual can pe possitive or negative hence we squared them.

# %% [markdown]
# Q. How you select best fit line in SSE?
#
# The linw which have min SSE that line is the best fit line.

# %% [markdown]
# Q. By which method we are selecting best fit line in linear regression?
#
# by using LSE method we select best fit line.

# %% [markdown]
# Q. What is overfitting and underfitting?
#
# overfitting:
#     When the model perform well on train datadset but not good on test dataset called overfitting.
#
# Overfitting:
#     When the model perform well on test datadset but not good on train dataset called overfitting.

# %% [markdown]
# Q.Why do we preffered adjested R^2 over R^2?
#
# If we keep on adding independent variables R^2 values atre tends to increase but in case of adjR^2 it will not increase
# if we add an insignificant independent variables.

# %% [markdown]
# Q.What is the use of regularization?
#
# Regularization is a technique that is used to tackel the problem of the overfitting model.
# Regularization is nothing but adding coefficient terms to the cost function so thet the terms are penalized and are small
# in magnitude.
# This essincially helps in capturing the trends in the data and at the same time prevents over fitting by not leting
# the model to becomes too complex.

# %% [markdown]
# Assumptions:
# 1.Load the Data and check/observe the data if it is contineous and have any dependent variable then use LR.
#
# 2.In LR model we use Straight line equation. y=mX+C
#
# 3.Procedure of finding out Best Fit Line: first we drow all the possible straight line on given points and then
#   calculate the Squared root of error (SSE) for each line. which line have max SSE that line be the best fit line.

# %% [markdown]
# # Steps in Model Creation
#
# 1. Load The Data
# 2. Missing Value Treatment
# 3. Outlier Treatment
# 4. Univeriate Analysis
# 5. Bivariate Analysis
# 6. Multicolinearity
# 7. Category Encoding/ Dummy variable
# 8. Train Test Split
# 9. Model Building
# 10. Model Validation

# %% [markdown]
# Questions on Missing Value Treatment

# %% [markdown]
# Q. What is Complete Case Analysis (CCA) in Machine Learning?
#
# Complete case analysis is not the best solution for handling the missing data, as by dropping the missing data, we are also losing some of the information of the data, and also it might be possible that sometimes the dropped missing data could also contain a piece of important information that the other data does not. So in most cases, while handling the missing data, complete case analysis is not preferred unless and until there is not any other option.When we have less than 5% missing data that time we can use CCA.

# %% [markdown]
# Q.Which Imputation is better for numerical data with outliers, mean or median? ##What is the reason behind them?
#
# How to do Missing value Treatment
# 1. if missing percentage of any varaible is more than 50percent we drop that variable
# 2. if missing percentage is less than 50
#      a. if the varibale is object then we replace missing value with mode
#      b. if the variable is numeric and if we have outlier in the variable replace missing with median
#      c. else if the variable is numeric with no outlier replace the missing value with mean

# %% [markdown]
# Q.What is Univariate Imputation of the missing data? Give Examples.
#
#
# In missing values imputations, the missing values are imputed using only the particular column of the respective missing values.
#
# For Example, if there is a missing value present in the Age column, then the missing value will only be imputed using the values of the Age column, Any of the other columns of the dataset will not be used for the imputation.

# %% [markdown]
# **Questions on Outlier Treatment

# %% [markdown]
# 1. What are Outliers? 🤔
#
# Outlier is an observation in a given dataset that lies far from the rest of the observations.
# That means an outlier is vastly larger or smaller than the remaining values in the data set.

# %% [markdown]
# 2. Why do they occur?
#
# An outlier may occur due to the variability in the data, or due to experimental error/human error.
#
# They may indicate an experimental error or heavy skewness in the data(heavy-tailed distribution).

# %% [markdown]
# 3. What do they affect?
# In statistics, we have three measures of central tendency namely Mean, Median, and Mode. They help us describe the data.
#
# Mean is the accurate measure to describe the data when we do not have any outliers present.
#
# Median is used if there is an outlier in the dataset.
#
# Mode is used if there is an outlier AND about ½ or more of the data is the same.
#
# ‘Mean’ is the only measure of central tendency that is affected by the outliers which in turn impacts Standard deviation.

# %% [markdown]
# 4. Detecting Outliers
# If our dataset is small, we can detect the outlier by just looking at the dataset. But what if we have a huge dataset, how do we identify the outliers then? We need to use visualization and mathematical techniques.
#
# Below are some of the techniques of detecting outliers
#
# Boxplots
# Z-score
# Inter Quantile Range(IQR)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Handling Outliers.how to deal with outliers?
#
# Below are some of the methods of treating the outliers
#
# 1.Trimming/removing the outlier
# 2.Quantile based flooring and capping
# 3.Mean/Median imputation

# %% [markdown]
# **Univariate Analysis

# %% [markdown]
# What is a Univariate Analysis?
#
# univariate data can be analyzed by descriptive analysis or inferential analysis.
# While inferential analysis is used to make predictions (or inferences) about the population,
# the descriptive analysis describes the data. In the descriptive analysis of univariate data, central tendencies,
# (mean, median, and mode) give us information about the central value in the data set, while the range, interquartile
# range, standard deviation, and mean deviation gives us information about the spread of the data. Frequency plots,
# histograms, and pie charts are also used in univariate data analysis to represent data visually.

# %% [markdown]
# **Bivariate Analysis

# %% [markdown]
# What is Bivariate Analysis ?
#
# It is a methodical statistical technique applied to a pair of variables (features/ attributes) of data
# to determine the empirical relationship between them. In other words, it is meant to determine any concurrent
# relations (usually over and above a simple correlation analysis).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Multicolinearity

# %% [markdown]
# Q.What Is Multicollinearity?
#
# Multicollinearity occurs when two or more independent variables in a data frame have a high
# correlation with one another in a regression model.
#
# Multicollinearity when two or more independent variables are highly correlated with each other.

# %% [markdown]
# Q.The Problem With Having Multicollinearity ?
#
# When Multicollinearity occures that means the model get biased toward that veriable.
# (biasness is just favourism).

# %% [markdown]
# Q.How we Detecting Multicollinearity?
#
# By Using VIF ( Variance Inflation Factor) we detect multicollinearity.
#
#         VIF=1/(1-R^2)

# %% [markdown]
# Q.How to Fix Multicollinearity?
#
# When you care more about how much each individual feature rather than a group of features affects the target variable, then removing multicollinearity may be a good option
# If multicollinearity is not present in the features you are interested in, then multicollinearity may not be a problem.
