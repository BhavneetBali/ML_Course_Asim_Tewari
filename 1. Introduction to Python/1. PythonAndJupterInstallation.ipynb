# %% [markdown]
# # Installing Python and Setting Up Jupyter Notebook
#
# This Jupyter Notebook will guide you through the steps to install Python and set up Jupyter Notebook on your system.

# %% [markdown]
# ---

# %% [markdown]
# ## Step 1: Install Python

# %% [markdown]
# ### For Linux:

# %%
# !sudo apt-get update
# !sudo apt-get install python3

# %% [markdown]
# ### For Mac:

# %%
# !brew install python3

# %% [markdown]
# ### For Windows:

# %%
# !choco install python

# %% [markdown]
# ---

# %% [markdown]
# ## Step 2: Verify Python Installation

# %% [markdown]
# To verify that Python has been installed successfully, run the following code:

# %%
# Check Python version
import sys
sys.version

# %% [markdown]
# ---

# %% [markdown]
# ### Step 3: Install Jupyter Notebook

# %% [markdown]
# To install Jupyter Notebook, run the following code:

# %%
# !pip install jupyter

# %% [markdown]
# ---

# %% [markdown]
# ### Step 4: Verify Jupyter Notebook Installation

# %% [markdown]
# To verify the Jupyter Notebook installation, run the following code:

# %%
# Check Jupyter Notebook version
# !jupyter notebook --version

# %% [markdown]
# ---

# %% [markdown]
# ### Step 5: Run Jupyter Notebook

# %% [markdown]
# To launch Jupyter Notebook, run the following code:

# %%
# !jupyter notebook
# Out:
# [I 09:37:46.976 NotebookApp] Serving notebooks from local directory: /Users/hirakdesai/Documents/Workspace/GitHub/ML_Course_Asim_Tewari/1. Introduction to Python
# [I 09:37:46.976 NotebookApp] Jupyter Notebook 6.4.0 is running at:
# [I 09:37:46.976 NotebookApp] http://localhost:8888/?token=e65f6c23cc9ca5c51806db0258f77e804bae4dc41842490c
# [I 09:37:46.976 NotebookApp]  or http://127.0.0.1:8888/?token=e65f6c23cc9ca5c51806db0258f77e804bae4dc41842490c
# [I 09:37:46.976 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation).
# [C 09:37:46.988 NotebookApp]
#
#     To access the notebook, open this file in a browser:
#         file:///Users/hirakdesai/Library/Jupyter/runtime/nbserver-94510-open.html
#     Or copy and paste one of these URLs:
#         http://localhost:8888/?token=e65f6c23cc9ca5c51806db0258f77e804bae4dc41842490c
#      or http://127.0.0.1:8888/?token=e65f6c23cc9ca5c51806db0258f77e804bae4dc41842490c
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Home Page of Jupyter

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.38.24 AM.png](<attachment:Screenshot 2024-01-29 at 9.38.24 AM.png>)

# %% [markdown]
# ## Creating a New Jupyter Notebook

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.40.13 AM.png](<attachment:Screenshot 2024-01-29 at 9.40.13 AM.png>)

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.41.22 AM.png](<attachment:Screenshot 2024-01-29 at 9.41.22 AM.png>)

# %% [markdown]
# ## Jupyter Notebook

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.42.47 AM.png](<attachment:Screenshot 2024-01-29 at 9.42.47 AM.png>)

# %% [markdown]
# ## Running our first code
# Run by clicking the `Run` button <br>
# or <br>
# Press `Shift + Enter`

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.47.39 AM.png](<attachment:Screenshot 2024-01-29 at 9.47.39 AM.png>)

# %% [markdown]
# ## Printing Patterns

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.54.01 AM.png](<attachment:Screenshot 2024-01-29 at 9.54.01 AM.png>)

# %% [markdown]
# ![Screenshot 2024-01-29 at 9.55.16 AM.png](<attachment:Screenshot 2024-01-29 at 9.55.16 AM.png>)

# %% [markdown]
# ----
